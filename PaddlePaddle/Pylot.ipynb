# %%
import  numpy as np
import matplotlib.pyplot as plt

np.random.seed(2020)
N =100
x = np.random.rand(N)
# 生成[0，1]的均匀分布

# %%
y = 10*x**2+np.random.rand(N)
colors = np.random.rand(N)
areas = (20*np.random.rand(N))
plt.scatter(x,y,s=areas,c=colors,alpha=0.5)
plt.show()
aw1
